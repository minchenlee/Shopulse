# %%
import os
import pprint
import asyncio
import aiohttp
from dotenv import load_dotenv
from googlesearch import search
from fake_useragent import UserAgent
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 電視資訊爬取

# %%
def fetch_page(url):
    # Placeholder for fetching a page; you'll replace this with actual fetching logic
    return requests.get(url)

def process_url(url, parser):
    try:
        response = fetch_page(url)
        if response.status_code == 200:
            result = parser(response.text, url)
            return result
        else:
            print(f"Failed to fetch {url}: Status code {response.status_code}")

    except Exception as e:
        print(f"Error fetching {url}: {e}")
        

def parse_page_for_tv(html_content, url):
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        text_content_list = soup.find_all('p')
        # print(text_content_list)
        soup = BeautifulSoup(str(text_content_list), 'html.parser')
        text = soup.getText()
        text = clean_text(text)
        return text
    
    except Exception as e:
        print(f"Error parsing {url}: {e}")


def clean_text(text):
    text = text.split('\n')

    # remove unwanted string
    text = [x.strip() for x in text]
    text = [x for x in text if x != '']
    text = [x for x in text if x != ' ']
    text = [x for x in text if x != "\n"]
    text = [x for x in text if x != ", "]
    text = [x for x in text if x != ","]
    text = [x for x in text if x != "'"]

    merged_text = '\n'.join(text)
    merged_text = merged_text.replace('\t', '')
    merged_text = merged_text.replace(', ', '')

    return merged_text


def write_to_file(text, file_name):
    if text is None:
        return
    
    with open(file_name, 'w') as f:
        f.write(text)

# %%
def run():
    url = input("Enter the URL: ")
    site = url.split('/')[2]
    print(url)
    output = process_url(url, parser=parse_page_for_tv)
    # write_to_file(output, f"./result/{site}.txt")
    print(output)

# %%
run()
# Out:
# https://agirls.aotter.net/post/62519
# [
# 2023/08/13
# by 電獺少女編輯室
# 這次小編來跟大家講解智慧電視怎麼挑，老規矩不會有品牌懶人包，而是跟大家介紹選購時該注意的事項，但歡迎各家廠商置入自薦，小編絕對會好好介紹 >.^雖然好像講了句廢話，但電視相比於其他電器產品，各廠牌對於不同等級的電視價位級距切得相當精準，可不是那種捏一下錢包，忍一個月不喝飲料就能接受的差距，所以抓好預算再來挑選電視比較好除了價錢外，接著要抉擇的是電視尺寸，並不是說大就好，電視大個幾吋不只價錢可能翻倍，家中又不一定擺得下，而且真的要大，也大不過現在越來越多人挑選的微型投影機（想看投影機推薦也可以敲碗小編）至於該挑多大，可以參考由 Sony 提出的建議參考網站：電視的建議觀賞距離是多遠？ | Sony TW現在買電視不一定只有追劇看電影，也有不少電玩玩家喜歡將 PS5、NS 等家用主機接上大螢幕，享受極致的娛樂體驗或與家人同樂，所以相對於畫質，可能更需要考慮高幀數或有補幀技術的電視；另外如果專門拿來看電影的用戶，除了畫質還會注重到喇叭的表現，所以先想想你的需求，再挑選適合你的電視才是最省時省力的這些，就是貴到市面上看不到、貴到買不起、超貴、很貴、平民選擇，小資族眼裡是這樣區分的結束（被打）真的要探討這幾種面板技術，多到可以再寫三篇文章也不為過，容小編用普通人也看得懂的方式介紹Micro LED：技術發展的目標，還沒量產，所以很貴，也看不太到mini LED：顯色鮮豔、亮度高、壽命長、省電、光暈會發散，技術還在發展所以很貴OLED：單點發色、能做到真正的純黑、亮度不高、有烙印問題壽命較短、顯色漂亮、技術逐漸成熟，目前畫質派的主流QLED：傳統 LED 的變體、亮度比 OLED 高、光暗對比優秀、顯色漂亮、壽命較 OLED 長、技術成熟，是小資族也能享受的奢華選擇UHD：根本不是面板而是畫質的稱呼，但很多廠牌會專門列出一個 4K UHD 系列來嚇唬大家，讓你以為有 D 的意志就很厲害一樣，沒有，就只是沒跟你說是傳統主流的液晶面板而已，技術相當成熟，俗又大碗現在稱智慧電視而不是螢幕，就是因為多了智慧聯網功能介面，讓你可以像使用手機一樣的操作電視，以往要追劇可能還要額外配備電視盒才能觀看 Netflix、YouTube 等串流平台，但現在主流的智慧電視都有內建此功能，可以直接觀看主流串流甚至下載 App 或遊戲，相當於一個超大螢幕手機但各品牌都有自己的介面，好不好用就跟手機果粉與安卓陣營一樣，各有千秋，要以你自己的喜好為準。不想用 Google TV 要買 Apple TV 也完全沒問題買智慧電視可不是小錢，而且依使用者習慣也有不同選擇，因為 OLED 的相對壽命不長（還是看習慣），所以保固也很重要，而每家廠牌即使用同樣的面板，但調色又各有不同，買之前最好還是到實體店面，以小編介紹的重點為基準，好好體驗一番，希望能幫到選擇困難的大家！（圖片來源：pexels）電獺少女 LINE 官方帳號好友募集中！精選每日科技新聞和促咪事件，還有各類 App 的密技心得，就差你沒加！,
# #samsung
# #sony
# #oled
# #lg
# #智慧電視
# #qled
# #microled
# 電獺少女編輯室是女孩一枚,
# 2023/11/22
# by Henley
# 家事救星,
# 2023/11/22
# by Henley
# 輕鬆製作一張完整的空白桌布,
# 2023/11/21
# by Henley
# 適合想找入門款的智慧手環的人嚐鮮嚐鮮,
# 2023/11/21
# by Henley
# 不用再按刪除鍵，或大費周章把整句話選起來刪掉了,
# 2023/11/21
# by Henley
# 三星 Galaxy S24 系列要來啦]

# %% [markdown]
# ### 關鍵字相關網頁爬取

# %%
def gather_by_keyword(keyword, num_results=5):
    result = search(keyword, num_results)
    result = list(result)

    for url in result:
        site = url.split('/')[2]
        print(url)
        output = process_url(url, parser=parse_page_for_tv)
        write_to_file(output, f"./result/{site}.txt")

# sum all txt in result folder
def concact_txt():
    text = ""
    for file in os.listdir("./result"):
        with open(f"./result/{file}", 'r') as f:
            text += f.read()
    return text


def save_txt(text, file_name):
    with open("./result/" + file_name + ".txt", 'w') as f:
        f.write(text)


# save all txt in result folder to one txt
def concact_and_save():
    text = concact_txt()
    save_txt(text, "sum_result")

# %%
gather_by_keyword("如何挑選電視？", num_results=7)
# concact_and_save()

# %%
# read sum_result.txt
with open("./result/sum_result.txt", 'r') as f:
    text = f.read()

list = text.split('。')

# %%
for sentence in list:
    print(sentence)
    print("-----")
# Out:
# [需要幫助？關注我們請輸入您的會員 Email 及密碼新顧客？ 創建會員帳戶忘記密碼？ 重置密碼請輸入您的 Email：還記得密碼？ 返回直接登入請在下方填寫有關信息：已經是會員？ 由此登入踏入智能科技的年代，大部份的傳統家電亦重新定位，例如過往屬於家庭電器的核心，提供一家大細娛樂的電視機，亦升級為智能產品，不再單純接收本地電視台的節目，而是可以利用內置的作業系統連接互聯網，直接串流播放更多影音平台的內容，帶來更多新的體驗
# -----
# 選購電視機的時候，大家會發現有很多專有名詞及規格，例如 4K UHD／FULL HD、HDR、曲面／平面、作業系統、尺寸等等，令人難以理解當中的意思，所以今次特別為大家進行出簡單解說，讓你輕鬆掌握選購要點
# -----
# 自 2018 年開始，大部份電視機品牌都相繼推出具有 4K UHD 畫質的電視機型號，而當中的 4K 就是指畫面解析度達到 3840×2160 或 4096×2160 像素達到 829 萬的規格
# -----
# 當 4K 與 FULL HD 比較的話，4K 畫面精細度會高達 4 倍，而伴隨 4K 出現的 UHD，就是指 HDR 高動態範圍，現時該技術的主流標準是 HDR 10
# -----
# 當應用於畫面的時候，就可以把影像的亮度提高到 1000 nits
# -----
# 簡單說明，就是令影像呈現得更有層次，色彩更為飽和及鮮豔當然這些技術都會直接反映在價格之上，因此一般來說 4K UHD 的電視會比 FULL HD 電視貴，但隨着此項技術普及，4K UHD 的電視價格，近來也逐漸由近萬元一部，降價至數千不等
# -----
# 除了畫質技術之外，部份品牌的機型採用了全新推出的曲面螢幕設計，雖然有絕佳的視覺體驗，但因為製作成本提高，售價也隨之而偏高，另外也因為螢幕是曲面的關係，只有坐在正中的人才可以享受最佳效果，稍為偏坐一旁的觀眾就會受到角度的影響，相反，平面螢幕的電視機就沒有以上的問題，雖然呈現出來的畫質沒有曲面的好，但電視機主要是為一家人提供娛樂，除非你是獨自一人生活，否則未必個個都可以享受曲面電視帶來的極致的畫面，所以大家在選購的時候，還是要留意平面及曲面的分別
# -----
# 除了以上的規格及技術之外，大家都會以螢幕的尺寸為選購考量，一般而言，大部份人都會在客廳安裝大尺寸的電視機，如房間使用的話，會選擇 43 吋這類較小型的電視，但原來未必是這樣的，因為當中還存在一個「最佳觀賞距離」
# -----
# 以 4K 電視的 65 及 55 吋螢幕為例，其最佳的觀賞距離約為 1.5 米至 2 米左右，假設一個百多、二百呎的小型單位，只要你與電視機之間具有這個最佳的觀賞距離，都可以選擇 50 吋以上的大電視，即使是住在蝸居，也一樣可以享受廣闊畫面帶來的視覺衝擊
# -----
# 常見市面上高階產品採用了量子點（QLED）技術，這些款式是應用了量子點技術背光源的電視，本質上仍屬於液晶電視，以藍色 LED 為光源，將採用量子點的光學材料放入背光燈與 LCD 面板之間，從而可以通過擁有尖銳峰值的紅、綠、藍三種光獲得鮮艷的色彩
# -----
# 採用 QLED 量子點顯示技術的電視覆蓋的色域可大於 100% NTSC，或達到 DCI-P3 廣色域顯示，可視為 LED 液晶電視的升級版
# -----
# 電視規格百花齊放，如何確保用家能獲得一致的影視娛樂體驗？那就需要更嚴謹的制式作統一規範
# -----
# 以大家最常用的 Netflix 來說，只要電視支援便能在影片頁面中看到對應制式「亮燈」
# -----
# 目前普遍支援的是針對高動態影像的 HDR10、Dolby Vision，可以呈現細節更精緻的視訊影像，增強色彩及動態範圍的顯示、讓內容更加逼真
# -----
# 而針對音效輸出製訂的 Dolby Atoms 則是一項環繞音效技術，首先應用於電影院，隨後逐步擴展至電視與家庭劇院；Dolby Atmos 能提供使用者身臨其境的環繞音效體驗，提供更加豐富的電影、音樂與語音之聽覺體驗
# -----
#  智能電視會搭載作業系統，例如 Samsung 的 Tizen、LG 的 webOS，而現時市場上最受注目的就是經 Google 官方推出的 Android TV 系統
# -----
# 雖然市場有部份較次級的品牌都標榜自己擁有以開源 Android 改裝而成的自家系統，但這些系統並不是 Android TV，而是廠商硬生生把原本應用於手機或平板電腦的系統及介面，強行移植到電視機上，雖然你仍可這類電視機可透過 apk 檔來安裝 app，因此在安全性上存有問題，甚至在未來無法更新 Android 版本而被迫停用
# -----
# 要標榜為 Android TV 的智能電視，需要獲得 Google 官方的合作認證，而配備這套系統的電視機也會採用標準制式，及提供統一的操作體驗，現時有推出 Android TV 電視機的品牌則包括有 Panasonic、SONY 及 TCL 等等
# -----
# 只要是具有 Android TV 系統的電視機，無論是哪一個品牌，其呈現出來的操作介面都以簡潔為主，用家可在電視機內登入個人的 Google 帳號，使用內建的 Chromecast、Google Assistant 智能語音助理，你亦可以直接從安全的 Google Play 市集中下載更多適用於電視的 Apps
# -----
# TCL P725 為市面上最平價的 QLED 智能電視之一，其採用 QLED 量子點 4K UHD 高清面板、並支援 PCI-P3 廣色域顯示及 Dolby Vision 杜比視界 HDR 解碼、HDR10+ 高動態影像制式影像顯示；在音效方面 P725 內置沉浸式ONKYO 2.1聲道音響系統，除了有 Dolby Atoms 杜比全景聲環繞解碼，亦加入了 AiPQ Engine 實時處理視聽內容
# -----
# TCL P725 系列 43 吋｜性價比高｜HK$4580｜點擊看更多詳情JX700 採用 Super Bright Panel屏幕呈現色彩豐富及銳利的4K HDR畫面，並提供廣闊的可視角度，並加入 HCX (Hollywood Cinema Experience) 處理器，由荷里活調色師調校畫面色彩，可呈現影院級影像色彩
# -----
# 同時Panasonic 亦為其加入 Filmaker 顯示模式，開啟後尤如分享由120名荷里活頂級導演調校的原視覺
# -----
# Panasonic JX700 系列 58 吋｜影院顯像｜HK$6850｜點擊看更多詳情 JX700 系列另有更細尺寸、價錢更為實惠的型號選擇，功能與上述的 58 吋型號相若，而且體積更細，或更適合寸金尺土的香港家居
# -----
# Panasonic JX700 系列 40 吋｜中價高清｜HK$4100｜點擊看更多詳情MiniLED 技術乃目前電視行業的最新技術之一，強調高對比度，TCL C825 系列就在採用 MiniLED 的同時加入DCI-P3 廣色域顯示、120Hz MEMC 流暢影像處理，在視聽享受方面，TCL C825 加入了 Dolby Atmos、Dolby Vision 的支援，又同時符合 IMAX Enhanced 認證標準，用來觀賞 Disney+ 上的 Marvel 超級英雄電影效果更出眾
# -----
# TCL C825 系列 55 吋｜Mini LED 新秀｜HK$10980｜點擊看更多詳情如果閣下追求的是更大屏幕的享受，TCL 旗下另一系列 P725 就有更大的 75吋型號可供選購，其支援 4K UHD 超高清廣色域顯示，Dolby Vision、Dolby Atmos 等皆一應俱全，預載 Android TV 系統的它已安裝了 Netflix、YouTube 等 Apps，幾近一插即用
# -----
# TCL P725 系列 75 吋｜大屏實惠｜HK$12980｜點擊看更多詳情提供優惠折扣、最新商品等信息
# -----
# 放心！您可以隨時取消訂閱~ 香港 Q 嘜優質服務 (藍金) 計劃，旨在表揚提供卓越服務之企業，評核項目包括服務水平、店舖設施環境、員工服務表現、 客戶服務水平等
# -----
# Q 嘜優質藍金網店認證卓越服務企業24hrs 便利店取貨｜送貨上門滿五百送 OK，滿一千送到屋企送貨純熟 迅速送出98% 客戶滿意出貨效率1 對 1 真人回答與我們聯繫訂閱獲取優惠折扣、最新商品信息
# -----
# © 2023 anlander 好貨加關注我們我們接受© 2023 anlander 好貨加][本網站會使用cookies. 若您繼續瀏覽本網站，代表您同意我們使用cookies
# -----
#  本網站會使用cookies. 若您繼續瀏覽本網站，代表您同意我們使用cookies
# -----
# ,
# 登入
# 追蹤訂單
# 帳戶
# 追蹤訂單
# 登出
# 大型液晶探索不同系列了解特色機種搜尋重點規格尋找最適大型液晶顯示器探索不同系列了解特色機種搜尋重點規格專用領域顯示器投影機探索不同系列了解特色機種搜尋重點規格商用投影機智慧照明探索不同系列遠端工作學習擴充底座/線材視訊鏡頭/軟體藍牙喇叭/配件大型商用顯示器數位電子顯示看板大型互動觸控顯示器解決方案商店選購最新產品與活動快速連結其他活動{{ result[0] }}{{ result[0] }}大型液晶探索不同系列了解特色機種搜尋重點規格尋找最適大型液晶顯示器探索不同系列了解特色機種搜尋重點規格專用領域顯示器投影機探索不同系列了解特色機種搜尋重點規格商用投影機智慧照明探索不同系列遠端工作學習擴充底座/線材視訊鏡頭/軟體藍牙喇叭/配件大型商用顯示器數位電子顯示看板大型互動觸控顯示器解決方案商店選購最新產品與活動快速連結其他活動,
# 登入
# 追蹤訂單
# 帳戶
# 追蹤訂單
# 登出
# 最新優惠活動，請參閱各產品線『新聞活動』專區最新優惠活動，請參閱各產品線『新聞活動』專區了解詳情BenQ 被非法業者冒用，以不實廣告企圖網路詐騙消費者BenQ 被非法業者冒用，以不實廣告企圖網路詐騙消費者了解詳情全館不限金額免運費，信用卡分期0利率全館不限金額免運費，信用卡分期0利率了解更多電視規格不斷推陳出新，現在主流電視規格到底怎麼看呢? 選購上又有哪些要注意的地方呢?為什麼市場上的電視規格這麼多，價差也不小，我有需要高階的電視嗎 ? 接下來就來說明要如何選購電視，怎樣買才最划算，其實只要掌握幾項重點，就能購買的超值又安心喔
# -----
# 好了，那就直接進入主題：臥室基本上建議 43 吋以上，客廳則是推薦選購 55 吋或 65 吋以上的電視，可以享受最佳視覺效果，並且選用 4K 機種
# -----
# 現在 4K 電視全面普及，購買 4K 電視才能夠在近距離觀看下，依然細緻動人，不會因為觀看距離空間不足而有顆粒感的情況
# -----
# 選購大尺寸電視前，必須先注意要擺放的位置是否空間受限
# -----
# A、確認桌子/櫃子擺放的寬度/高度與電視機的尺寸是否能夠配合：先量測家裡桌子/櫃子長、寬、高尺寸，然後再上網對照電視機的尺寸能否擺的下
# -----
# B、若電視擺放空間有搭配裝潢的話，必須先確認電視尺寸然後再請畫圖施工，避免電視機擺放空間不足，影響功能，如 IR 接收視窗被擋到
# -----
# C、先確認可以擺放尺寸範圍後，再來決定購買的尺寸，可避免選好規格之後擺不下的問題
# -----
# ▲可參考電視機的尺寸，來對照擺放空間是否足夠，尺寸(含底座)這欄的資訊才是我們要看的
# -----
# 一般來說使用電視大部分基本都會搭配數位電視台或是 MOD、第四台等機上盒的內容，然後再依據常使用的情境來做選擇，例如使用遊戲主機的遊戲玩家，用來看電影或是追劇等等
# -----
# 延伸閱讀 : 從使用情境輕鬆選擇你的護眼大型液晶 電視的技術也分為多種不同的規格，而各種面板技術都有其優缺點，接下來就來介紹如何做挑選：明暗對比高、黑階的的部分深邃，因此使用在看電影以及玩遊戲的對比對上較佔優勢，暗部細節清楚，明暗對比高
# -----
# 可視角廣，任何平視角度看過來均不會有色偏，色材的表現較 VA 面板佳，響應速度快，但缺點是對比度較差，這部分就必須要有取捨
# -----
# 面板像素本身帶有自發光有機體
# -----
# OLED 面板的黑階部分極為深邃，因為顯示純黑色時面板不發光，拉大明暗之間的對比，且 OLED 面板的顏色發色非常濃郁，再加上視角廣不色偏，近年來等同於頂級機種的代名詞
# -----
# 缺點為成本高昂，且螢幕容易殘留烙痕，使用時間久了容易會有色衰，功耗也比較高，OLED 由於可視角度、反應速度、色彩、省電等各方面都優於其它面板，是追求頂級享受的選擇
# -----
# QLED 電視是三星所創立的面板等級，其本質為 VA 面板加上廣色域的背光模組，或是使用色彩最純淨的量子點光源作為背光源，革命性的實現全色域顯示，目前 QLED 面板(DCI-P3 90%~95%)，色彩的表現是介於廣色域技術與 OLED 面板(DCI-P3 97%~99%)之間，但本身是 VA 面板沒有烙印問題，價格也比 OLED 面板便宜些，是中高階電視的另一項選擇，但缺點是對比度仍追不上 OLED 面板
# -----
# WCG 廣色域的用途是增加色彩，鮮豔紅、鮮果綠等更深的顏色表現
# -----
# 電視只能產生有限度的顏色，跟你在真實世界中看到的顏色是有所差距的
# -----
# 而廣色域的功能就是產生栩栩如生的顏色
# -----
# Rec709 為普通色域，是針對 HDTV 高畫質電視所訂的國際通用統一色彩標準，DCI-P3 是美國電影行業推出的廣色域標準，為了滿足 UHD 最低標準，至少要能夠覆蓋 90% 的 DCI-P3 色域，也就是說 90% 以上 DCI-P3 是目前 HDR 規格顯示器的基本色彩要求，新一代色域標準 BT.2020，為未來電視色彩技術的新標準，目前顯示設備尚無法完整顯示 100% BT2020 色域
# -----
# Mini LED 是目前最新的直下式背光技術，較傳統的 LED 縮小 40 倍左右體積，因此更容易實現區域控光，而採用 Mini LED 所製造的 Mini LED 電視，不僅對比度高、色彩完整、色域廣、顏色更飽和，螢幕鮮豔度也更接近 OLED，而且成本也較 OLED 低 20~30%，對於想找畫質好，價格又不希望太高的人，提供一個很好的選擇
# -----
# 賣場通常都會陳列各品牌的電視，種類之多也是令人眼花撩亂，至於如何在現場辨別面板的畫質好壞? • 秘訣 1 ：看懂規格不吃虧，面板等級越高，價格也越高，面板等級排名分別是：OLED>QLED>VA=IPS，而搭載新世代 mini LED 背光的面板，其主要的訴求就是追上 OLED 的畫質，且價格更親民些，想追求高畫質，又不想太傷荷包的話，可以從搭載 Mini LED 的電視選起
# -----
# 而 VA 與 IPS 面板則主打平價需求，因此可以先從需求來選擇，高階畫質選擇 OLED、搭載 Mini LED 背光技術面板、QLED 等面板為主，一般需求則以 VA、IPS 等面板為主的選購，並符合 4K、HDR、Dolby Vision、廣色域這幾個重點來選購
# -----
# • 秘訣 2：選定好規格之後，實際比較各品牌實際畫面的效果，是否符合自己本身的需求，以看的順眼為主
# -----
# 賣場要注意的就是所有的電視都會將亮度調亮，或是對比拉高，尤其 IPS 機種因為本身對比低，整機出廠設定時都會調亮以補足對比不足
# -----
# 到賣場後，先確認商家是否使用「賣場模式」，建議調整成一般家裡的「家用模式」後，再進行比較，而 VA 與 IPS 機種則可以利用相同場景做一比較，可分別觀察亮部與暗部的細節，再比較顏色的差異，一般來說 VA 面板在暗部與亮部場景的細節表現會比 IPS 面板多，對常玩遊戲或是看電影的需求來說會是比較好的選擇
# -----
# ① Android TV(Google TV)：Android TV 是基於 Android 平台開發給 TV 專用的平台，Google TV 是 2021 之後的升級版，簡潔的介面，並且內建大家熟悉的 Google Play Store、常見的影音 APP 如 YouTube、Disney+、Netflix 都可以下載安裝，延伸閱讀 : 如何在電視上觀賞 Netflix?  對電視硬體支援度高，APP 種類多元，支援 Google 助理等功能、Chromecast 等功能，Google 親自開發的平台，也是最容易使用的平台
# -----
# ② Linux 平台(webOS、Tizen)：基於 Linux base 所開發的平台，各家廠商可以套用自家的 UI，打造不一樣的連網功能，其中最為代表的是 Samsung Tizen 與 LG Webos，支援自家的 APP 市集，主流的 YouTube、Netflix 、Disney+ 也都有支援，也支援語音搜尋，缺點是內容豐富度稍微不足，暫時還無法與 Android TV 抗衡的平台
# -----
# ③  Linux 平台(VIDDA)：VIDDA Smart OS 是一套基於 Linux 內核開發的智慧電視操作系統與平台，通過優化設計簡化了傳統的智慧電視用戶介面，可以上網並添加各種娛樂享受的應用程式，例如：Netflix/YouTube/Prime vide/Disney+/etc...，VIDDA 為用戶提供個性化且更簡單、更快速、更智慧的順暢使用體驗
# -----
# 語音控制支援範圍：語音控制系統常見的有 Amazon Alexa、Google Assistant
# -----
# 以台灣市場來說，Google Assistant 實用性比較高，Alexa 在台灣尚未支援中文，語音控制支援的範圍為常見的功能搜尋：如今天天氣如何、我要看怪奇物語、開啟 Netlfix..等語音助理的功能
# -----
# 語音家居支援度？如何判定是否與家中智能家居設備相容：智慧家庭在國內盛行的主要有幾大陣營，分別是 Apple HomeKit、Google Home、米家等，各家都有其支援的裝置，若是小米的愛好者，則會發現米家同系列的產品支援度最好，Apple HomeKit 主要使用者偏向於 iOS 裝置，而智慧家電的種類還在慢慢的增加，以 Google 為主的 Google Home 則是支援最廣的智慧家庭平台，藉由語音助理的控制如 Google Nest mini 等裝置，可以直接操作智能家居設備，例如下達 OK Google ，打開電視的指令，因此在選購智慧家電時，則是選擇支援同系統為主，避免產生不相容的情況，而像 Samsung、LG 也各自發展各自的智慧家庭，如 Samsung Smarthings、LG ThinQ 等
# -----
# 智慧家庭平台比較表：① 影像/聲音模式：一般電視都會針對不同的使用模式提供方便的設定，影像模式如：清晰、標準、Eco、劇院、運動、遊戲、HDR、isf 專業模式，常看球賽的話，就可以將影像模式調整為運動模式
# -----
# 聲音模式的設定則是針對使用情境來調整低音、中頻、高音的部分，幫助頻率之間的平衡、增加樂器的張力、幫助樂器的清晰度與分離，常見的設定模式有：標準、劇院、清晰人聲、運動、音樂、遊戲
# -----
# 也可以根據你使用的情境來做設定，進階的音效模式如 DTS:Virtual X 或是 Dolby Atoms 音效則是可提供，隨著每個畫面的轉換，更細膩的音質表現、聲音來自四面八方的環繞感以及震撼的立體音效
# -----
# ② 進階影像設定包含哪些項目 ? 調整這些項目對畫質有什麼影響 ? 不同的進階影像設定會帶來不同的觀影效果，不同的環境或是觀賞片源都有較佳的設定方式，進階調校的好可以帶來更佳的觀賞效果，適合進階的玩家來使用
# -----
# • 背光/對比度/色彩飽和度/銳利度/色調的調整：電視出廠都會有預設最佳值，若覺得畫面不夠亮可以調整背光的亮度，調高暗部細節會越高，但調太高則是會顯得灰浮，對比度可改變畫面亮區與暗區的對比、色彩不夠飽和可以調整色彩的濃度、銳利度可以調整影像的鮮明和清晰度，不宜調太高容易起白邊、色調則是針對顏色調整通常都會維持在 50，提高會使畫面偏向綠色，若發現電視畫面顏色或是亮度異常，都可以調整影像的設定
# -----
# • 白平衡/七色調教/Gamma 調整/色域切換 : 白平衡用來調整色溫、亮度以及紅綠藍色增益控制來設定色彩平衡、七色調教用來微調紅色、綠色、藍色、青色、洋紅色和黃色的色彩空間、Gamma 調整藉由調整設定以補償輸入訊號的亮度、色域設定可顯示的色彩範圍
# -----
# ③ 選購電視時可比較各家設定選單是否提供詳細的設定• 到賣場時不妨拿起遙控器打開設定選單，看一下有哪些設定是可以讓消費者做調整的，並非越複雜越好，而是設定介面是否清楚好用，而設定後也能夠看得出差異性，對於不懂這些設定的玩家，也可以看有哪些已定義好的功能讓一般消費者選者，例如像是針對清晰、標準、劇院、運動、遊戲或是專業效果等
# -----
# • 另外像是畫面的解析度、HDR、第四台畫質不清楚等，是無法透過選單來設定，這些都是需要硬體與軟體搭配來使用的
# -----
# ① 面板規格：面板規格會有幾項組成因素，分別是面板解析度、發光方式、反應時間/刷新頻率、亮度/靜態度比/分區調光、色域、Input Lag 等技術規格，以下一一做說明：• 面板解析度 : 面板規格是 1080P 或是  4K 解析度(3840*2160)，可以從面板解析度來判別
# -----
# • 發光方式：背光技術的 LED、Mini LED 或是自發光技術的 OLED，依畫質好壞分別是 OLED>Mini LED>LED
# -----
# • 反應時間 VS 刷新頻率：相同都是 60Hz 刷新頻率的電視，表示 1 秒鐘顯示 60 張畫面，每張畫面存在時間 16ms，倘若反應時間越低(1ms VS 10 ms)，表示可以顯示的畫面時間愈長(15ms VS 6ms)，也就是說反應速度越低，換場的速度越快，在高速移動下，低反應時間的面板會看到較少的殘影，畫面會更流暢；刷新頻率則是越高看起來越順暢，越高的刷新率表示一秒鐘內可以顯示刷新的畫面張數，越高殘影越低，120Hz 的螢幕刷新頻率看起來會比 60Hz 來的流暢許多，可以防止畫面快速移動產生的動態模糊的感覺
# -----
# • 亮度/靜態對比度/分區調光：SDR 規格的最高亮度是 100 nits，市面上電視最少都能達到 250 nits，而 HDR 規格最高亮度是 1000 nits，不過只能在高規格的電視上看到，一般規格 HDR 電視的亮度大多在 400~600 nits 之間，選購上可以注意一下這些數據；市面上的電視大多標示動態對比，但這些都只是行銷的訴求，而靜態對比度為面板原生的對比度，選購上以高的靜態對比優先，高對比度對於畫面的清晰度、細節表現、灰階層次都很有幫助；由於 LED 電視本身面板並不發光，需要靠 LED 燈泡模組進行發光，背光會影響觀看時的對比度與亮度表現，支援分區調光的面板，其背光機種 LED 是分布在面板的正後方，控光會較明顯，會有較高的對比度及更多明暗部細節
# -----
# • 分區調光(直下式 LED VS. 直下式 Mini LED)：沒有區域調光的面板，會因為無法精準控光，例如在顯示月光的畫面時，因為明暗畫面交接處無法精準顯示，會產生光暈，而分區調光可以得到較好的畫面品質，逐漸成為中高端電視的標配，普通 LED 顆粒較大，無法做到精細調光而 Mini LED 因為顆粒較小，有更多的背光分區，可以實現更精細的調光，尤其適合 HDR 的動態畫面呈現，達到低延時、不閃爍的區域調光、實現全域色彩還原，因此透過分區數+控光能力強可以媲美 OLED 畫質
# -----
# ▲Mini LED 背光擁有較高的對比度，可以呈現全黑的畫面• 色域： 面板會分一般色域：NTSC 68~72% 跟廣色域：NTSC 80%~85% 的面板及高色域：DCI-P3 94~99% 的面板，而一般色域通常不會做標示，支援廣色域的面板，通常都會在消費廣告看的到，若對畫質要求較高，支援廣色域是必備的條件之一
# -----
# • Input Lag：表示訊號輸入到電視，電視畫面開始對應的時間，通常看電視或是電影並不會有什麼感覺，但若是接上 PS5 或是 Xbox Series X/S、Switch 等電視遊樂器，只要是 Input lag 超過 100ms 你都可以感覺得出來，理想的 Input lag 應該在 40ms 以下
# -----
# ② 晶片規格(CPU)：CPU 晶片負責影像解碼、處理與輸出，設計良好的晶片可以得到更佳影像輸出細節和生動的色彩
# -----
# • 核心數/處理時脈重要嗎 ? CPU 的核心數與時脈已經不是重點，通常也不會出現在規格型錄上，廠商會依照電視的功能來規劃合適的晶片來對應，像是執行 4K 撥放/升頻/影像優化/APP 執行等等,在賣場不妨測試轉台的順暢度、4K 影像撥放、APP 執行等等的功能，測試有沒有流暢即可
# -----
# • 記憶體與儲存空間的選擇 ? 記憶體也會影響 CPU 處理程式的時間，不過這部分也不會出現在規格型錄上，基本上電視出廠的記憶體都夠用，裝一些常用的 APP 也都夠用，所有的資料還是會透過網路串流的部分作處理，這些廠商都考量過，不用太擔心記憶體不夠的問題
# -----
# • 選購盲區(手機/電腦/電視晶片大不同)：我們在選購手機或電腦時，大多會注意 CPU 核心與處理速度，記憶體的多寡，因為這會決定這台電腦或是手機在執行程式時夠不夠順暢，而電視選購的重點則是在畫質的部分去做挑選，有沒有支援 4K 撥放、HDR 支援的規格、有沒有聯網功能、APP 是否有支援我要看的節目等等，對觀賞經驗比較有影響的因素去做比較
# -----
# ③ 端子(輸入 / 輸出) : 負責聲音的輸出端子:數位音源 SPDIF、數位同軸 COAXIAL、類比音訊輸出端子 Line out、耳機 Headphone Jack、及 HDMI 對 ARC/eARC(音訊回傳通道)的支援度，可依外接音響設備支援的端子做選擇；負責影像的輸入端子：對於擁有較多娛樂設備的玩家，選擇足夠的影像輸入端子顯得相當重要，其中又必須注意支援 HDMI 2.0/2.1 有幾組，永遠保留更多的 HDMI 2.0/2.1 接口，對未來才能擁有更多的擴充性
# -----
#  ④ 滿足 PS5/Xbox Series X 次世代主機規格：想完整體驗 PS5 或是 XBOX Series X 主機的魅力，該選擇什麼規格的電視，才能夠符合呢?以下就跟著我們一起探討：• HDMI 2.1： HDMI 支援動態元數據，代表著可支援最新 HDR 技術，HDR10+ 與 Dolby Vision，最高傳輸頻寬來到 48Gbps，可支援 4K 原生 120Hz；8K 原生支援至 60Hz，代表想要讓 PS5/XBOX Series X 發揮完整功能，其第一要件就是 HDMI 2.1 的支援
# -----
# • VRR(Variable Refresh Rate)可變更新率：假設 PS5 的畫面輸出偵率是 120 fps、而電視輸出偵率是 60 fps，這中間的輸出差異會造成畫面的斷續延遲與撕裂，而 VRR 就可以消除，畫面的斷續延遲和撕裂的現象，藉此產生更為平順的影像
# -----
# • ALLM(Auto Low Latency Mode)自動低延遲模式：許多電視設定中，都有一個「遊戲」模式，目的就是為了適應遊戲操作的快速反應，降低自搖桿輸入指令後到畫面產生動作的延遲感，但缺點就是必須由使用者手動去切換，而 ALLM 就是省去使用者手動切換的麻煩，只要電視偵測所插入的 HDMI 2.1 裝置，全自動判斷是否要啟動低延遲模式，省下不少設定時間
# -----
# ⑤ 是否有防火材料： 電視長時間運作會產生高溫，在電視的主要材質如電視外殼是否選用防火塑膠等防火材質，電源線則是越粗越好並符合安規，都可以列入選購上的參考資料，有些需要到賣場才能實際摸的到
# -----
# ① 藍光：藍光是指波長 380nm-495nm 之間的可見光，藍光是可見光裡能量最大的，穿透力強，可以穿過瞳孔直達視網膜中間的黃斑部，長時間接觸會產生黃斑部病變，因此選購上以低藍光功能的機種較能夠保護眼睛
# -----
# ② 不閃屏：有區域調光的面板，會因為無法精準控光，例如在顯示月光的畫面時，因為明暗畫面交接處無法精準顯示，會產生光暈，而分區調光可以得到較好的畫面品質，逐漸成為中高端電視的標配，普通 LED 顆粒：一般採用 PWM 背光技術的電視，當背光低於 100%，PWM 會造成背光快速的開與關，形成屏閃的現象，一秒鐘約可達 250 次的閃爍，看久了會造成眼睛的不適，而mini LED因為高分區背光的調控，只能使用 PWM 架構，但只要 PWM 的頻率能達到 960Hz，就能趨近不閃頻的作用；DC 調光採用直流調整的方式可讓背光穩定的發光，即為不閃屏，有不閃屏技術的電視可以有效減緩長時間觀看電視螢幕的疲勞，有沒有不閃屏，用下來效果真的非常有感
# -----
# ③ Audio Only：螢幕關閉模式，搭配 YouTube、Spotify 等音樂撥放站台，將電視搖身一半為隨選音響，並且關閉螢幕可以節省電源，算是實用的功能
# -----
# A、賣場模式介紹：為什麼賣場賣的電視看起來不論是清晰度、對比、立體感，都比家裡的要好呢? 賣場的電視為了呈現最好的一面，通常會用高解析度的片源，調高對比與亮度並且讓色彩艷麗一點，所以賣場的電視看起來效果總是比家裡好，不過要知道賣場模式並不適合長時間家用觀賞，因為亮度調到最大，不僅耗電加上長時間觀看都比較傷眼力
# -----
# B、電視內正版與盜版應用程式如何區分 ? 一般電視內建的 APP 市場都是正版的應用，若有商家打著額外的軟體或是主打免費的第四台、最新電影，則必須小心是否為盜版軟體，選購上也必須特別小心避免觸法
# -----
# C、機台陳列方式會影響畫質嗎 ? 賣場的電視陳列在一起，方便消費者做個比較，不過還是得留意，若遇到有特殊業務促銷的機種，可能撥放高解析度的影片、對比、亮度與色彩鮮豔一點，讓畫面看起來更動人，而沒有促銷的機種就調的黯淡一點，這樣消費者在現場選購時就很容易被左右操控，破解的方式，就必須現場看訊號源及設定是否有被調整過，另外有時也會把高亮度/低亮度/高色域/低色域的機型混和陳列，混淆消費者進行特定機型推銷，這時候先做功課就顯得重要必須，以免買到就後悔
# -----
# D、HDR 與 SDR 畫質差異，我要怎麼區分 ? HDR 是 High Dynamic Range 的意思，HDR 畫面的亮部會更亮，暗部會更暗，色彩表現能力更好，尤其是畫面中高亮度的色彩，具有更好的還原性；SDR 是 Standard Dynamic Range 的意思，對比度較差，明暗之間的漸層變化小，亮部的色彩偏淡，甚至是產生色偏，下圖中 HDR 畫質下，獵魔士臉部的陰影層次分明、細節都能展現、色彩還原度高，明顯比 SDR 臉部細節盡失，暗部不夠顯，還產生色偏，整體觀感 HDR 在各方面明顯勝出
# -----
# 延伸閱讀 : 4K HDR可以有什麼特別？ E、該如何在賣場調整成適合自己在家中觀賞的設定值 ? 為了完整重現家中觀賞的設定值，來做為你購買的依據，這時候就必須要調整賣場電視的設定值，可以利用現場的電視遙控器，打開設定選單，並且將影像模式調整為標準或是劇院模式(看電影用)，這時候就會比較接近一般家裡電視所看到的設定值
# -----
# A、看不懂規格怎麼辦 ? 如何避免誤觸地雷: 買電視前要先做功課，功課做足才有能夠買到最適合自己的電視，看不懂規格沒關係，可以透過網路或是詢問店家自己的需求，預算價格帶、電視使用地點、電視用途(第四台、運動節目、電影、HDR 電影、遊戲...)，清楚這些需求，專家才能夠建議適合你的品牌與規格
# -----
# B、善用爬文機制：聰明的網友也可以到各大論壇去爬文或是發問，透過網友的討論，來解答自己的需求，並且 Google 看看該電視型號有沒有災情等等發生，而常見的網路資源如：① 各大品牌官網：各大品牌官網都會發表最新的電視機種，並且詳細解說規格與主打功能，是最容易與直接獲得資訊的管道
# -----
# ② 各大論壇 : Mobile01 影音/高畫質視界版、PTT Digital Home、巴哈姆特等論壇，論壇會有各式電視開箱、電視推薦發問..等等，網友都會熱心的解答
# -----
# 電視不論是規格、功能、畫質都會因為不同的品牌而有所不同，選購前先確認好本身的需求，再鎖定尺寸、功能、畫質、預算等需求，並爬文了解各廠牌機種的優缺點，鎖定幾個品牌機種後最後再到賣場去做實際比較，相信消費者都能夠找到最適合自己闔家觀賞的電視
# -----
# Netflix 影集越來越受到台灣觀眾歡迎，想要用大畫面觀看，除了選擇有內建Netflix 的智慧電視之外，也可以使用機上盒/遊戲機/外接筆電
# -----
# 此篇文章分享如何使用這些設備看到最棒畫質、擁有最好體驗，以及在採買設備時應該注意什麼，以確保可以看到正版授權 Netflix
# -----
# 2023如何挑選智慧電視?  智慧電視已是市場主流趨勢，3C達人Sam分享簡單的三個選購步驟:認識智慧電視的平台有哪些、有哪些方便的特點、選購時還要注意哪些規格，讓你買電視更輕鬆簡單!4K及4K HDR內容並不是遙不可及，提供的管道越來越多，在電視大螢幕上享受好畫質並不難，文章介紹幾個享受4K HDR 內容的方法
# -----
# 如何依照居家空間，選擇適合的電視尺吋，要考慮的因素不只有沙發到電視的「距離」，也需要將 「電視畫質」納入考量
# -----
# 4K 是近幾年大尺寸顯示器的熱門話題
# -----
# 4K正式名稱為Ultra HD簡稱UHD，解析度是3840×2160，畫素可達到829萬，解析度為Full HD的四倍
# -----
# 4K電視為時勢所趨，價格越來越親，且內容取得逐漸更加多元化
# -----
# 面對各品牌琳瑯滿目的4K電視，怎麼選一台好看、好用又好適合自己的呢？我們建議從幾個角度來挑選支援HDR電視可表現出亮處層次分明及暗處清楚可見之特性；簡單來說，HDR相對於SDR能看到更多明暗細節、再現豐富色彩
# -----
# 最適合看電影的120Hz面板，影像播放流暢，搭配ISF認證專業技師的色彩調校模式，加上媲美劇院的環場音效，忠實呈現電影本色，提供極緻高畫質影音享受！你家就是電影院！最新護眼Google TV，內建NETFLIX、YouTube，支援Disney+，並採用BenQ獨家雙認證護眼科技不閃屏與低藍光，讓你高畫質連網追劇零時差
# -----
# 您覺得本篇文章有幫助嗎?感謝您的回饋！訂閱BenQ官方電子報給熱愛新鮮事的您，不定期提供實用新知與限時活動訂閱電子報,
# 產品
# BenQ 商店
# 購物相關問題
# 支援服務
# BenQ 相關網站
# 更多資訊
# Copyright © 2023 BenQ all rights reserved.Copyright © 2023 BenQ all rights reserved.][2023家電節能補助、貨物稅減徵項目只有冷氣＆冰箱＆除濕機
# -----
# 所以……今年沒有補助電視～今年沒有補助電視～今年沒有補助電視啊～（很殘念！所以要說三次！）回到正題，是說如何選購一台適合自己或是全家人的電視，又該如何挑選適合的電視尺寸、電視面板？這些可都是相當重要的課題
# -----
# 畢竟大家從早上出門一直忙到天黑進了溫暖的家，最舒服的當然就是整個人攤在客廳沙發上滑滑手機、看看電視、追追劇，你說是不是？「好想換電視」的OS應該在多數人心中環繞了千百次吧？但電視規格多，對多數人來說其實是有些艱澀，看了還是一頭霧水、無法做決定、該如何是好？小編整理挑選電視的四大重點，讓你一次搞懂，輕鬆買到一台最適合自己的電視
# -----
# 選購一台適合自己的電視，最基本要從尺寸、畫質、面板、連網需求四大重點來判斷，不過最~最~最~重要的還是要清楚自己的需求，這台電視是打算用來追劇？打電動？買來給長輩使用？（這時簡單方便反而是最重要的了）或是希望有高端的影音享受？又或是價格考量？總而言之，沒有最好的，只有最適合自己的，接下來小編會依挑選電視的四大重點來一一為大家解析如何挑選電視
# -----
# 近幾年大尺寸電視的價格愈來愈親民，部分國產品牌的50吋電視甚至不到一萬元就能入手
# -----
# 但一昧追求大尺寸的電視並不是個好方法、長期來說也會對觀看者的視力造成不良的影響，小編建議挑選電視尺寸時至少有以下兩個因素需要考量：簡單來說，相同尺寸的電視，當電視畫質（解析度）愈高時，觀賞距離就可以愈近
# -----
# 若以目前逐漸成為主流的4K電視來說：但小編建議在選購電視前，還是要去實體門市親自體驗一下觀看的感受，才會最清楚符合個人觀影感受的電視
# -----
# 只能說，電視愈大看起來真的是爽度愈高啊！台灣索尼電視產品部主任王源威接受採訪時曾說，因為4K HDR技術已臻成熟，包括畫質銳利度、亮度和色彩都有提升，過去在近距離觀看2K（1080p）電視畫面時會出現顆粒感、模糊或殘影等等，容易造成眼部不適，如今4K電視發展成熟，近距離已能看到所有細節，電視最佳觀賞距離已迅速縮短
# -----
# 電視尺寸與最適觀賞距離對照表可以參考以下電視評測機構RTINGS.com的建議：電視解析度決定了畫面的精細程度，在電視尺寸相同的情況下，如果解析度越高，就代表著畫面中能呈現的像素（pixel）愈多，播放的電視畫面也就越細緻、越清晰
# -----
# 目前市場上較主流的電視解析度大致分為以下三種，以電視解析度從低到高依序排列為Full HD < 4K UHD < 8K UHD：不過，倘若欲購買4K電視，最好鎖定今年新品，因為相較於去年的舊機種，今年新機強化了色彩、對比和色域、電視OS也都有優化及更新並陸續支援Apple AirPlay 2，已能使用iPhone或iPad畫面以鏡像輸出到電視上觀看，因此，想要入手一台新電視擁有較新科技、享受新功能的話，千萬別買舊機種
# -----
# 4K超畫質電視有哪些？哪些電視有4K？●4K 量子尖端智慧處理器●雙視光增豔技術●超能動態加速器+●專業玩家模式●廣域視角●立體景深強化●魔術音效 Lite簡單來說，像素可以比喻為呈現出「色彩的點點」
# -----
# 若以「50吋FHD」跟「50吋4K UHD」兩台電視來比較，後者的電視框框中的「色彩點點」就比前者多了「4倍」那麼多，「色彩點點」越多當然畫面就越細緻，所以不同解析度的電視畫質差異有多大可想而知
# -----
# 近幾年4K UHD電視的漸漸普及，多數媒體也陸續推出符合4K畫質的相關內容（如：公視/MOMOTV等電視頻道、myVideo/YouTube/Netflix等線上串流平台、PS5等遊戲），而且4K UHD電視價格相較FHD電視已經不會差異太大
# -----
# 一般來說，電視至少會使用5~8年不等，就使用的長遠性考量，建議此時若要選購電視的話可直上4K UHD電視
# -----
# 而8K電視因為起步較晚，可對應畫質的內容相當稀少，而且目前8K電視售價昂貴，可以先觀望後續的發展再入手喔
# -----
# 電視面板大致可分為以下三種，也各有優缺點，可以視自己的需求來選擇：大家平常外出，為了方便都是用手機來看影片或追劇，但是回到家裡，一定會想要追求大尺寸的電視才是最舒服的呀！目前使用連網電視較為普及的應用就是觀看網路影片，若你也想要用智慧連網電視來觀看網路影集、電影，除了購買智慧連網電視是一種選擇之外，其實還有以下兩種替代方式，也能輕鬆將非智慧聯網電視升級為Smart TV：如果你家中的舊電視沒有連網功能，又想要用可負擔的預算把傳統電視升級為連網電視，最快速的方式就是選購以下配件之一：如果你喜歡用電視追劇又剛好要換電視，當然就是直接選購一台有智慧連網功能的電視啦！但選購智慧連網功能的電視時，建議要挑選擴充性較佳的電視（有內建商城的機型讓使用者可自行下載APP的機型），這對於後續的使用會較為便利喔
# -----
# 看更多智慧連網電視優惠
# -----
# ●4K最新智能聯網Android 11 TV  ●4K HDR、HQLED技術打造專業廣色域●HDMI 2.1搭載VRR、ALLM、eARC，MEMC動態補償由於55吋電視為目前市場主流，所以在文章最後，小編整理多款熱銷55吋電視推薦給大家，其中有55吋4K電視推薦、55吋智慧聯網電視推薦、OLED電視推薦、低藍光護眼電視推薦，若您最近剛好有購買電視機的需求，不妨參考小編的建議，選擇一台符合自己需求的電視機吧！●東芝六真色PRO●Google Assistant 中/英文語音助理●內建應用程式 Netflix、愛奇藝、YouTube、Google Play●三規HDR：HDR10+HLG+Dolby Vision●CEVO 4K HDR + Ultra Essential PQ 影像處理●支援藍牙●支援Airplay 2鏡射投影●智慧型單一遙控器可連結外接裝置●多重視窗： 大小螢幕同步享受●智慧管家整合藍牙Wifi紅外線● 全陣列 LED 背光●XR 認知智慧處理器●多音域環繞揚聲技術● 內建Chromecast投放● Google Assistant中英語音搜尋● 支援台灣最熱門最豐富的中英APPS● SMART智慧連網系統●超高絢睛彩屏技術●百萬動態對比●內建WIFI●內建三組HDMI數位影音端子●4K60p超高解像技術●HDR極致明暗細節層次技術●內建Wifi / 雙系統投屏●獨家無段式藍光調節●獨家DolbyVisionIQ●Google認證最新安卓11.0 TV●120hz更新率●量子點顯色更提升超高清解析3840 X 2160●全生態HDR10高動態對比●區域調光●HDMI2.1●內置HIFI低音砲●安卓智慧連網系統●手機鏡射功能(可支援APPLE/Android手機鏡射)●16W後低音砲●智能降噪●動態色彩矯正技術●自動音量調整●全機三年保固●AI晶片(α9)●美國UL低藍光護眼雙認證●AI語音互動●AI音效5.1聲道● 4K Master OLED 面板 深邃黑高畫質●Smooth Motion Drive Pro 動態影像完美呈現●WiFi 内藏 無線網路連結● 認知智慧處理器 XR●XR 原色顯示 PRO●XR OLED 對比增強● 解析度:1360*768● SGS低藍光/杜比音效作者：麥哥、菜蔡子文章發布日期：2021/03/15、最後更新日期：2023/02/02若您對本文中介紹的【Panasonic 4K連網LED液晶電視 TH-55JX650W)】有興趣，又恰巧有台灣大哥大門號續約/新申辦門號/攜碼的需求，歡迎點選超值 e即棒 專案👆👆👆，即可在台灣大哥大網路門市用更優惠的專案價帶走【Panasonic 4K連網LED液晶電視 TH-55JX650W】
# -----
# ●Android TV 10.0，量身打造精彩娛樂●Google play服務 Internet App 使用 (Youtube,Netflix,Amazon 等)●4K IPS LED明亮面板 若您對本文中介紹的” 【TOSHIBA】55型4K安卓六真色PRO廣色域LED液晶顯示器有興趣，又恰巧有台灣大哥大門號續約/新申辦門號/攜碼的需求，歡迎點選電信門號超值專案👆👆👆，即可在台哥大網路門市用更優惠的專案價帶走 【TOSHIBA】55型4K安卓六真色PRO廣色域LED液晶顯示器
# -----
# 文字編輯／Columnist從麥哥到麥叔到麥爸，人生不斷進階，也希望透過書書寫寫讓口袋也快速進階
# -----
#  ◆ 看更多麥哥的文章 快加入myfone online 會員，首次購物送MyVideo影音大禮包，還能不定時享有更多好康唷！OP響樂生活讀者專享myfone online折價券序號：（加入會員登錄下方序號即可使用）● 折1050序號：OPBLOG1050（滿15,000）● 折550序號：OPBLOG550（滿6,000）● 折350序號：OPBLOG350（滿1,800） ● 折120序號：OPBLOG120（滿500） 覺得這篇文章有幫助嗎？趕快分享給身邊的朋友，或將「OP響樂生活」加入我的最愛，讓達人教你買
# -----
# 想知道更多台灣大哥大電信門號申裝和3C購物好康就來「myfone online」！更多優惠好康與售後保障，盡在myfone online😍，立刻來逛逛！👇👇👇,
# 你必須登入才能發表留言
# -----
# ][
# 2023/08/13
# by 電獺少女編輯室
# 這次小編來跟大家講解智慧電視怎麼挑，老規矩不會有品牌懶人包，而是跟大家介紹選購時該注意的事項，但歡迎各家廠商置入自薦，小編絕對會好好介紹 >.^雖然好像講了句廢話，但電視相比於其他電器產品，各廠牌對於不同等級的電視價位級距切得相當精準，可不是那種捏一下錢包，忍一個月不喝飲料就能接受的差距，所以抓好預算再來挑選電視比較好除了價錢外，接著要抉擇的是電視尺寸，並不是說大就好，電視大個幾吋不只價錢可能翻倍，家中又不一定擺得下，而且真的要大，也大不過現在越來越多人挑選的微型投影機（想看投影機推薦也可以敲碗小編）至於該挑多大，可以參考由 Sony 提出的建議參考網站：電視的建議觀賞距離是多遠？ | Sony TW現在買電視不一定只有追劇看電影，也有不少電玩玩家喜歡將 PS5、NS 等家用主機接上大螢幕，享受極致的娛樂體驗或與家人同樂，所以相對於畫質，可能更需要考慮高幀數或有補幀技術的電視；另外如果專門拿來看電影的用戶，除了畫質還會注重到喇叭的表現，所以先想想你的需求，再挑選適合你的電視才是最省時省力的這些，就是貴到市面上看不到、貴到買不起、超貴、很貴、平民選擇，小資族眼裡是這樣區分的結束（被打）真的要探討這幾種面板技術，多到可以再寫三篇文章也不為過，容小編用普通人也看得懂的方式介紹Micro LED：技術發展的目標，還沒量產，所以很貴，也看不太到mini LED：顯色鮮豔、亮度高、壽命長、省電、光暈會發散，技術還在發展所以很貴OLED：單點發色、能做到真正的純黑、亮度不高、有烙印問題壽命較短、顯色漂亮、技術逐漸成熟，目前畫質派的主流QLED：傳統 LED 的變體、亮度比 OLED 高、光暗對比優秀、顯色漂亮、壽命較 OLED 長、技術成熟，是小資族也能享受的奢華選擇UHD：根本不是面板而是畫質的稱呼，但很多廠牌會專門列出一個 4K UHD 系列來嚇唬大家，讓你以為有 D 的意志就很厲害一樣，沒有，就只是沒跟你說是傳統主流的液晶面板而已，技術相當成熟，俗又大碗現在稱智慧電視而不是螢幕，就是因為多了智慧聯網功能介面，讓你可以像使用手機一樣的操作電視，以往要追劇可能還要額外配備電視盒才能觀看 Netflix、YouTube 等串流平台，但現在主流的智慧電視都有內建此功能，可以直接觀看主流串流甚至下載 App 或遊戲，相當於一個超大螢幕手機但各品牌都有自己的介面，好不好用就跟手機果粉與安卓陣營一樣，各有千秋，要以你自己的喜好為準
# -----
# 不想用 Google TV 要買 Apple TV 也完全沒問題買智慧電視可不是小錢，而且依使用者習慣也有不同選擇，因為 OLED 的相對壽命不長（還是看習慣），所以保固也很重要，而每家廠牌即使用同樣的面板，但調色又各有不同，買之前最好還是到實體店面，以小編介紹的重點為基準，好好體驗一番，希望能幫到選擇困難的大家！（圖片來源：pexels）電獺少女 LINE 官方帳號好友募集中！精選每日科技新聞和促咪事件，還有各類 App 的密技心得，就差你沒加！,
# #samsung
# #sony
# #oled
# #lg
# #智慧電視
# #qled
# #microled
# 電獺少女編輯室是女孩一枚,
# 2023/11/22
# by Henley
# 家事救星,
# 2023/11/22
# by Henley
# 輕鬆製作一張完整的空白桌布,
# 2023/11/21
# by Henley
# 適合想找入門款的智慧手環的人嚐鮮嚐鮮,
# 2023/11/21
# by Henley
# 不用再按刪除鍵，或大費周章把整句話選起來刪掉了,
# 2023/11/21
# by Henley
# 三星 Galaxy S24 系列要來啦][9/21/202221/9/20222022/09/21想要購買電視卻不知道尺寸怎麼看，或不知道該怎麼測量家裡電視的尺寸，42吋、55吋差很多嗎？超簡單測量法讓你不用對著數字苦惱
# -----
# 一般市面上主流的電視螢幕比例為16：9，較為傳統型電視的比例為4：3，但考量了人們的觀看感受和視野角度等因素所以進行調整，另外也有因應需求特別打造的加長版螢幕
# -----
# 電視尺寸通常以英吋表示螢幕對角線的大小，所以只要測量螢幕對角線的長度就能知道你需要的電視尺寸了，那麼液晶電視螢幕有哪些尺寸可以挑選呢？較常看到的尺寸通常在32～70吋之間，以下是針對16：9主流電視螢幕的尺寸介紹，假如你不熟悉英吋單位也可以用公分來判斷
# -----
# 在選購時總會希望能像在電影院一樣擁有超大的電視螢幕，但電視尺寸越大越好嗎？以下就讓小編來幫你解答
# -----
# 這並不是一個正確的觀念，如果買到不合適的電視尺寸再加上長時間的觀看，除了在觀看感受上不舒服以外還會對你和家人造成以下3大危害：  ● 頸椎受傷 ● 眼睛肌肉用力過度 ● 長期觀看可能會導致頭暈電視觀看清晰度是以解析度做為衡量標準，4K 電視的解析度會比 Full HD 電視來的高，觀看體驗也會比較好
# -----
# 選擇正確的電視尺寸才能保證在觀看感受上的品質，看到這邊可別再有電視尺寸越大越好的這種迷思了
# -----
# 在挑選尺寸時應該注意以下3點，才能買到最適合你的電視，讓每一分錢都花得有價值
# -----
# 電視的擺放方式可以分為壁掛式和直接放在電視櫃2種類型，假如你的家庭格局較小，又選擇擺放在電視櫃上，那麼可能不適合過大電視尺寸，以免居家空間較為擁擠
# -----
# 另外電視牆和電視的比例搭配也要注意，才不會影響美觀
# -----
# 目前電視根據解析度主要可分為4k電視和Full HD這兩種類別，解析度越低則所需要的觀賞距離就更遠，4k電視的解析度較高，視覺效果也比Full HD來的更好，在相同的尺寸下所需的觀賞距離就不用像Full HD這麼多
# -----
# 想了解更多4k電視可以看這篇－延伸閱讀看電視最舒服的視角大約是20度左右，所以電視尺寸的挑選應該要以觀賞距離做為主要的考量，如果座位與電視的距離越近就會建議選擇越小的尺寸
# -----
# 而最佳觀賞距離的判斷也非常簡單，只要將你想選購的電視吋別乘上3倍就是最佳的觀賞距離
# -----
#  讓我們 LG 電視 OLED C2 極致系列的尺寸為例，讓大家更清楚知道如何以電視尺寸找出最合適的觀賞距離
# -----
# ]
# -----

# %% [markdown]
# ### 商品資訊爬取

# %%
def fetch_page_advanced(url):
    ua = UserAgent()
    user_agent = ua.random
    headers = {'User-Agent': user_agent}

    # add headers to request
    html_content = requests.get(url, headers=headers)
    return html_content

def parse_page_for_momo(html_content, url):
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        tab_list = soup.find_all(class_ = 'TabContentD selected')
        # print(tab_list)

        product_list = []
        for tab in tab_list:
            product = parse_momo_for_product(str(tab), url)
            product_list  = product_list + product

        return product_list
    
    except Exception as e:
        print(f"Error parsing {url}: {e}")
        
def parse_momo_for_product(html_content, url):
    try:
        soup = BeautifulSoup(html_content, 'html.parser')
        # Find all <li> tags
        products = soup.find_all('li')

        product_list = []
        # Iterate through each product
        for product in products:
            product_name = product.find('h3', class_='prdName').get_text(strip=True)  # Extract product name
            product_price = product.find('b', class_='money').get_text(strip=True)  # Extract product price
            product_link = 'https://www.momoshop.com.tw' + product.find('a')['href'] # Extract product link
            product = {
                'name': product_name,
                'price': product_price,
                'link': product_link
            }
            product_list.append(product)
        return product_list
    
    except Exception as e:
        print(f"Error parsing {url}: {e}")

def print_html_context(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    print(soup.prettify())

# %%
# print out the html content
url = input("Enter the URL: ")  
html_content = fetch_page_advanced(url).text
product_list = parse_page_for_momo(html_content, url)

# %%
product_list
# Out:
# [{'name': '【Philips 飛利浦】55吋4K android聯網液晶顯示器(55PUH8257)',
#   'price': '12999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11932211&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【RANSO 聯碩】43型FHD低藍光液晶顯示器(RF-43VA3)',
#   'price': '9990',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8822321&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【JVC】50型 Apple認證AirPlay2 4K HDR 飛輪體感連網液晶顯示器(50TG)',
#   'price': '9999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10628869&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【小米】55型智慧顯示器 A2 (L55M7-EATWN)',
#   'price': '10999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11616098&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERAN 禾聯】50型4K HDR 智慧聯網液晶顯示器(HD-50SDF43)',
#   'price': '12900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11078663&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【DigiKing 數位新貴】轟霸重低音32吋美學無邊低藍光液晶顯示器(DK-V32HN11)',
#   'price': '3999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10887660&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【JVC】65型飛輪體感+AI語音4K HDR連網液晶顯示器(65G)',
#   'price': '15988',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11310199&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】43型IPS 4K Google TV AirPlay2杜比視界全景聲六真色PRO液晶顯示器(43C350LT)',
#   'price': '9999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11707174&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERAN 禾聯】43型全面屏4K HDR聯網液晶顯示器(43HYA-F1)',
#   'price': '11900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11143372&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】58型六真色PRO杜比視界全景聲4K安卓液晶顯示器(58C350KT)',
#   'price': '12999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9852678&str_category_code=2900900120&mdiv=2900900120-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】43型IPS 4K Google TV AirPlay2杜比視界全景聲六真色PRO液晶顯示器(43C350LT)',
#   'price': '9999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11707174&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【AOC】55吋 4K QLED Google TV 智慧顯示器(55U8030)',
#   'price': '14999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11662457&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TCL】75型 4K QLED 144Hz Google TV 量子智能連網顯示器 基本安裝(75C735)同75C736',
#   'price': '34900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11879416&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【Haier 海爾】75型 4K HQLED Google TV 智能聯網液晶顯示器(LE75PUX2)',
#   'price': '27988',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10968125&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】55型IPS 4K Google TV AirPlay2杜比視界全景聲六真色PRO液晶顯示器(55C350LT)',
#   'price': '13999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11738342&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【AOC】50吋 4K QLED Google TV 智慧顯示器(50U8030)',
#   'price': '9999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11410535&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【AOC】65吋 4K QLED Google TV 智慧顯示器(65U8030)',
#   'price': '15999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11410534&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】50型4K Google TV AirPlay2杜比視界全景聲六真色PRO液晶顯示器(50C350LT)',
#   'price': '11999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11707173&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TCL】55型 4K QLED 144Hz Google TV 量子智能連網顯示器 基本安裝(55C735)同55C736',
#   'price': '17900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11879415&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SONY 索尼】BRAVIA 65型 4K HDR Full Array LED Google TV顯示器(XRM-65X90K)',
#   'price': '47600',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10213349&str_category_code=2900900863&mdiv=2900900863-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【RANSO 聯碩】43型FHD低藍光液晶顯示器(RF-43VA3)',
#   'price': '9990',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8822321&str_category_code=2900900084&mdiv=2900900084-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【CHIMEI 奇美】32型 HD低藍光顯示器_不含視訊盒(TL-32B100)',
#   'price': '5590',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10467925&str_category_code=2900900084&mdiv=2900900084-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【JVC】65吋Google認證4K HDR連網液晶顯示器(65L)',
#   'price': '17888',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7998867&str_category_code=2900900084&mdiv=2900900084-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【CHIMEI 奇美】43型 HD低藍光顯示器_不含視訊盒(TL-43B100)',
#   'price': '9590',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10467926&str_category_code=2900900084&mdiv=2900900084-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【Philips 飛利浦】55吋4K android聯網液晶顯示器(55PUH8257)',
#   'price': '12999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11932211&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【RANSO 聯碩】43型FHD低藍光液晶顯示器(RF-43VA3)',
#   'price': '9990',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8822321&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【JVC】50型 Apple認證AirPlay2 4K HDR 飛輪體感連網液晶顯示器(50TG)',
#   'price': '9999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10628869&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【小米】55型智慧顯示器 A2 (L55M7-EATWN)',
#   'price': '10999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11616098&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERAN 禾聯】50型4K HDR 智慧聯網液晶顯示器(HD-50SDF43)',
#   'price': '12900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11078663&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【DigiKing 數位新貴】轟霸重低音32吋美學無邊低藍光液晶顯示器(DK-V32HN11)',
#   'price': '3999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10887660&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【JVC】65型飛輪體感+AI語音4K HDR連網液晶顯示器(65G)',
#   'price': '15988',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11310199&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】43型IPS 4K Google TV AirPlay2杜比視界全景聲六真色PRO液晶顯示器(43C350LT)',
#   'price': '9999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11707174&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERAN 禾聯】43型全面屏4K HDR聯網液晶顯示器(43HYA-F1)',
#   'price': '11900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11143372&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TOSHIBA 東芝】58型六真色PRO杜比視界全景聲4K安卓液晶顯示器(58C350KT)',
#   'price': '12999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9852678&str_category_code=2900900158&mdiv=2900900158-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【RANSO 聯碩】43型FHD低藍光液晶顯示器(RF-43VA3)',
#   'price': '9990',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8822321&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERAN 禾聯】50型4KHDR AIoT智慧聯網液晶顯示器+視訊盒(HD-50TDF66)',
#   'price': '9888',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8537434&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【JVC】65吋Google認證4K HDR連網液晶顯示器(65L)',
#   'price': '17888',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7998867&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERSUN 豪爽】32吋HDR雷神重低音液晶顯示器(HS-32C06)',
#   'price': '3490',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8514412&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【DECAMAX】24型FHD液晶顯示器(DMJ-24A2)',
#   'price': '5499',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6853314&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SANLUX 台灣三洋】24型HD液晶顯示器/無視訊盒SMT-24MA3(含運不含拆箱定位)',
#   'price': '4480',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6050156&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【HERAN 禾聯】55型4KHDR AIoT智慧聯網液晶顯示器+視訊盒(HD-55TDF66)',
#   'price': '11999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8537436&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SANLUX 台灣三洋】24型HD液晶顯示器+視訊盒(SMT-24MA3)',
#   'price': '4788',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=5881129&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SANSUI 山水】75型4K HDR智慧連網液晶顯示器(SLHD-751VT)',
#   'price': '29999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8332643&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SANLUX 台灣三洋】50型4K液晶顯示器+視訊盒(SMT-50MU5)',
#   'price': '12690',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8236102&str_category_code=2900900161&mdiv=2900900161-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【Philips 飛利浦】55吋QLED量子點安卓智慧顯示器 單機 箱損特價品(55PUH8816)',
#   'price': '19999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10828591&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【CHIMEI 奇美】福利品-50型4K HDR低藍光智慧連網顯示器+視訊盒(TL-50M600福利品)',
#   'price': '9900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=12058605&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【Philips 飛利浦】50型 4K UHD LED Android 顯示器 特價B品(50PUH8516)',
#   'price': '14365',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11795945&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【CHIMEI 奇美】福利品 55吋大4K HDR安卓11 Google連網液晶顯示器+視訊盒(TL-55R700福利品)',
#   'price': '15900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11082942&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SAMPO 聲寶】43型FHD低藍光杜比音效液晶顯示器(EM-43FB600福利品)',
#   'price': '7200',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11270225&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SAMPO 聲寶】50型4K HDR低藍光液晶顯示器(EM-50FC610 福利品)',
#   'price': '9800',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10800995&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【SAMPO 聲寶】55型4K QLED量子點安卓11智慧聯網顯示器(QM-55UCH620特選福利品)',
#   'price': '15900',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11922955&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【TECO 東元】43吋 FHD 低藍光 液晶顯示器+壁掛安裝(TL43A9TRE福利品)',
#   'price': '9000',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11948888&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【Philips 飛利浦】55吋QLED量子點安卓智慧顯示器 單機 箱損特價品(55PUH8816)',
#   'price': '16888',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=12094214&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'},
#  {'name': '【Philips 飛利浦】55吋QLED量子點安卓智慧顯示器 箱損特價品(55PUH8816)',
#   'price': '19999',
#   'link': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=12089131&str_category_code=2900900840&mdiv=2900900840-bt_9_002_01&ctype=B&Area=DgrpCategory'}]
